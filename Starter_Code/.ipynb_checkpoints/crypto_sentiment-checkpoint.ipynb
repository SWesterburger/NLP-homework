# %%
import os
import pandas as pd
# %matplotlib inline

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")

# %%
# Test if properly loaded
type(api_key)
# Out:
# str

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_articles = newsapi.get_everything(
    q="Bitcoin OR BTC OR bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Test sample article 

bitcoin_articles['articles'][10]

# Print total number of articles

print(f"Total articles about Bitcoin: {bitcoin_articles['totalResults']}")
# Out:
# Total articles about Bitcoin: 3739

# %%
# Fetch the Ethereum news articles

ethereum_articles = newsapi.get_everything(
    q="Ethereum OR ETH OR ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Test sample article 

ethereum_articles['articles'][10]

# Print total number of articles

print(f"Total articles about Ethereum: {ethereum_articles['totalResults']}")
# Out:
# Total articles about Ethereum: 1377

# %%
# Create the Bitcoin sentiment scores DataFrame

btc_sentiment = []

for article in bitcoin_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiment.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiment)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#                    date                                               text  \
# 0  2020-05-29T10:03:35Z  Our robot colleague Satoshi Nakaboto writes ab...
# 1  2020-06-09T23:45:00Z  The Winklevoss twinsthe brothers Mark Zuckerbe...
# 2  2020-05-25T09:46:32Z  Our robot colleague Satoshi Nakaboto writes ab...
# 3  2020-06-05T10:17:20Z  Our robot colleague Satoshi Nakaboto writes ab...
# 4  2020-06-02T14:19:53Z  <ul><li>Famed investor Michael Novogratz tweet...
#
#    compound  positive  negative  neutral
# 0     0.507      0.09       0.0     0.91
# 1     0.000      0.00       0.0     1.00
# 2     0.507      0.09       0.0     0.91
# 3     0.507      0.09       0.0     0.91
# 4     0.000      0.00       0.0     1.00

# %%
# Create the ethereum sentiment scores DataFrame

eth_sentiment = []

for article in ethereum_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiment.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiment)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#                    date                                               text  \
# 0  2020-06-17T19:00:35Z  Editor’s note:Andreessen HorowitzsCrypto Start...
# 1  2020-06-08T08:38:44Z  Our robot colleague Satoshi Nakaboto writes ab...
# 2  2020-05-20T19:00:17Z  Editors note:Andreessen Horowitzs Crypto Start...
# 3  2020-06-03T22:55:42Z  For developers looking to quickly build identi...
# 4  2020-06-15T13:25:41Z  Akron, Ohio, the hometown of LeBron James and ...
#
#    compound  positive  negative  neutral
# 0     0.000      0.00       0.0     1.00
# 1     0.507      0.09       0.0     0.91
# 2     0.000      0.00       0.0     1.00
# 3     0.000      0.00       0.0     1.00
# 4     0.000      0.00       0.0     1.00

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  96.000000  96.000000  96.000000  96.000000
# mean    0.171115   0.063177   0.027177   0.909687
# std     0.362775   0.064012   0.052556   0.083186
# min    -0.817600   0.000000   0.000000   0.618000
# 25%     0.000000   0.000000   0.000000   0.872000
# 50%     0.114750   0.070000   0.000000   0.910000
# 75%     0.507000   0.090000   0.042750   1.000000
# max     0.859100   0.280000   0.215000   1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#        compound   positive   negative    neutral
# count  97.00000  97.000000  97.000000  97.000000
# mean    0.18889   0.072474   0.027330   0.900186
# std     0.39231   0.070574   0.051352   0.079861
# min    -0.80740   0.000000   0.000000   0.665000
# 25%     0.00000   0.000000   0.000000   0.851000
# 50%     0.22630   0.065000   0.000000   0.910000
# 75%     0.50700   0.121000   0.050000   1.000000
# max     0.91980   0.335000   0.223000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum (.06 vs .07)
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum (.920 vs .859)
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum (.335 vs .280)

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary 
# At first glance I did not specifically find any stopwords that I feel should be added - hence below just to show you methodology
sw_addon = {}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    
    # Lemmatize Words into root words
    lemmatizer = WordNetLemmatizer() 
    lem = [lemmatizer.lemmatize(word) for word in words]

    # Convert the words to lowercase remove stopwords
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
    
    return tokens

# %%
# Create a new tokens column for bitcoin
btc_df['tokens']=[tokenizer(word) for word in btc_df['text']]
btc_df.head()
# Out:
#                    date                                               text  \
# 0  2020-05-29T10:03:35Z  Our robot colleague Satoshi Nakaboto writes ab...
# 1  2020-06-09T23:45:00Z  The Winklevoss twinsthe brothers Mark Zuckerbe...
# 2  2020-05-25T09:46:32Z  Our robot colleague Satoshi Nakaboto writes ab...
# 3  2020-06-05T10:17:20Z  Our robot colleague Satoshi Nakaboto writes ab...
# 4  2020-06-02T14:19:53Z  <ul><li>Famed investor Michael Novogratz tweet...
#
#    compound  positive  negative  neutral  \
# 0     0.507      0.09       0.0     0.91
# 1     0.000      0.00       0.0     1.00
# 2     0.507      0.09       0.0     0.91
# 3     0.507      0.09       0.0     0.91
# 4     0.000      0.00       0.0     1.00
#
#                                               tokens
# 0  [robot, colleague, satoshi, nakaboto, writes, ...
# 1  [winklevoss, twinsthe, brother, mark, zuckerbe...
# 2  [robot, colleague, satoshi, nakaboto, writes, ...
# 3  [robot, colleague, satoshi, nakaboto, writes, ...
# 4  [ullifamed, investor, michael, novogratz, twee...

# %%
# Create a new tokens column for ethereum
eth_df['tokens']=[tokenizer(word) for word in eth_df['text']]
eth_df.head()
# Out:
#                    date                                               text  \
# 0  2020-06-17T19:00:35Z  Editor’s note:Andreessen HorowitzsCrypto Start...
# 1  2020-06-08T08:38:44Z  Our robot colleague Satoshi Nakaboto writes ab...
# 2  2020-05-20T19:00:17Z  Editors note:Andreessen Horowitzs Crypto Start...
# 3  2020-06-03T22:55:42Z  For developers looking to quickly build identi...
# 4  2020-06-15T13:25:41Z  Akron, Ohio, the hometown of LeBron James and ...
#
#    compound  positive  negative  neutral  \
# 0     0.000      0.00       0.0     1.00
# 1     0.507      0.09       0.0     0.91
# 2     0.000      0.00       0.0     1.00
# 3     0.000      0.00       0.0     1.00
# 4     0.000      0.00       0.0     1.00
#
#                                               tokens
# 0  [editors, noteandreessen, horowitzscrypto, sta...
# 1  [robot, colleague, satoshi, nakaboto, writes, ...
# 2  [editors, noteandreessen, horowitzs, crypto, s...
# 3  [developer, looking, quickly, build, identity,...
# 4  [akron, ohio, hometown, lebron, james, seat, u...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_all_text = []
for token in btc_df['tokens']:
    for text in token:
        btc_all_text.append(text)
btc_bigram_counter = Counter(ngrams(btc_all_text, n=2))
print(dict(btc_bigram_counter.most_common(10)))
# Out:
# {('satoshi', 'nakaboto'): 40, ('bitcoin', 'btc'): 25, ('robot', 'colleague'): 20, ('colleague', 'satoshi'): 20, ('nakaboto', 'writes'): 20, ('writes', 'bitcoin'): 20, ('every', 'fucking'): 20, ('fucking', 'daywelcome'): 20, ('daywelcome', 'another'): 20, ('another', 'edition'): 20}

# %%
# Generate the Ethereum N-grams where N=2
eth_all_text = []
for token in eth_df['tokens']:
    for text in token:
        eth_all_text.append(text)
eth_bigram_counter = Counter(ngrams(eth_all_text, n=2))
print(dict(eth_bigram_counter.most_common(10)))
# Out:
# {('char', 'ethereum'): 12, ('bitcoin', 'btc'): 9, ('satoshi', 'nakaboto'): 8, ('char', 'bitcoin'): 6, ('ether', 'eth'): 6, ('ethereum', 'eth'): 5, ('char', 'robot'): 4, ('robot', 'colleague'): 4, ('colleague', 'satoshi'): 4, ('nakaboto', 'writes'): 4}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(btc_all_text)
# Out:
# [('bitcoin', 99),
#  ('char', 96),
#  ('satoshi', 44),
#  ('nakaboto', 40),
#  ('btc', 38),
#  ('today', 23),
#  ('tell', 21),
#  ('whats', 21),
#  ('going', 21),
#  ('robot', 20)]

# %%
# Get the top 10 words for Ethereum
token_count(eth_all_text)
# Out:
# [('char', 97),
#  ('ethereum', 45),
#  ('bitcoin', 30),
#  ('ha', 27),
#  ('blockchain', 18),
#  ('new', 15),
#  ('transaction', 13),
#  ('eth', 13),
#  ('btc', 11),
#  ('user', 11)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the word cloud
def processed_text(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    return big_string

# %%
# Generate btc and eth words
btc_words = processed_text(btc_all_text)
eth_words = processed_text(eth_all_text)

# %%
# Bitcoin word cloud
btc_wc = WordCloud(collocations=False).generate(btc_words)
fig = plt.figure()
plt.imshow(btc_wc)
plt.show()

# %%
# Ethereum word cloud
eth_wc = WordCloud(collocations=False).generate(eth_words)
fig = plt.figure()
plt.imshow(eth_wc)
plt.show()

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together

btc_text = []

for text in btc_df['text']:
    text = text
    btc_text.append(text)
    
big_string_btc = ' '.join(btc_text)

# %%
# Run the NER processor on all of the text
btc_doc = nlp(big_string_btc)

# Add a title to the document
btc_doc.user_data['title'] = 'Bitcoin NER'

# %%
# Render the visualization
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , tell you whats been going on with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in … [+3000 chars]
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Winklevoss
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  twinsthe brothers
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Zuckerberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  allegedly stole the idea for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fromare making a movie about themselves,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deadline
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reported
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . If that doesnt seem masturbatory enough, r… [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +2657
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chars] Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , tell you whats been going on with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in … [+3004 chars] Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark class="entity" style="background: #aa9cfc; pa

# %%
# List all Entities
for ent in btc_doc.ents:
    print (ent, ent.label_)
# Out:
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# The Winklevoss WORK_OF_ART
# Mark Zuckerberg PERSON
# Facebook ORG
# Deadline PERSON
# this week DATE
# +2657 ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Michael Novogratz PERSON
# Monday DATE
# bitcoin GPE
# $10,000 resistance MONEY
# Novogratz PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Apple ORG
# Microsoft ORG
# trillion-dollar MONEY
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin BTC GPE
# first ORDINAL
# 2009 DATE
# Satoshi Nakamoto ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Reuters
#  ORG
# Goldman Sachs ORG
# five CARDINAL
# bitcoin GPE
# Wednesday DATE
# Goldman ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# 2020 DATE
# a big year DATE
# Bitcoin GPE
# Bitcoin GPE
# Bitcoin PERSON
# mid-May DATE
# nearly 400,000 CARDINAL
# Satoshi ORG
# nearly 300,000 CARDINAL
# Andreessen Horowitzs ORG
# Crypto Startup School ORG
# 45 CARDINAL
# U.S. GPE
# seven-week DATE
# Andreessen Ho PERSON
# Andreessen ORG
# Crypto Startup School ORG
# 45 CARDINAL
# U.S. GPE
# seven-week DATE
# Andreessen H FAC
# Zoom PERSON
# Tesla PERSON
# this year DATE
# nearly 99% PERCENT
# 250,000 MONEY
# minutes TIME
# today DATE
# Kitco News ORG
# U.S. GPE
# CoinDesk PERSON
# the National Science Foundation ORG
# KRNC ORG
# Bitcoin GPE
# Bitcoin GPE
# 2009 DATE
# Canadian NORP
# QuadrigaCx ORG
# Canada GPE
# more than $1 MONEY
# Rich Dad PERSON
# Robert Kiyosaki PERSON
# the weekend DATE
# Nick Bilton‘s PERSON
# American Kingpin PERSON
# the last few weeks DATE
# Ross Ulbricht PERSON
# Dread Pirate Roberts WORK_OF_ART
# The Silk Road FAC
# December 2019 DATE
# First ORDINAL
# the most volatile days DATE
# VPN ORG
# one CARDINAL
# Psystar GPE
# OpenCore Computer WORK_OF_ART
# this week DATE
# Hackintosh ORG
# Velociraptor WORK_OF_ART
# Apple ORG
# PARIS GPE
# FRANCE GPE
# Bitcoin GPE
# February 01 DATE
# 201 CARDINAL
# +5599 ORG
# Game From Scratch WORK_OF_ART
# YouTube LAW
# Bitcoin GPE
# Litecoin and Ethereum ORG
# Mark Andrews PERSON
# St Helens PERSON
# England GPE
# Liverpool Crown C ORG
# +2411 ORG
# the past year DATE
# Privnotes.com ORG
# Privnote.com ORG
# more than 7% PERCENT
# 1,000 MONEY
# first ORDINAL
# Wednesday DATE
# Techmeme ORG
# 3:20 PM  TIME
# May 19 DATE
# bitcoin GPE
# Bitfarms GPE
# Saint Hyacinthe GPE
# Quebec GPE
# March DATE
# 19, 2018 DATE
# Bitcoin GPE
# first ORDINAL
# Tesla ORG
# 10% PERCENT
# Elon Musk PERSON
# Tesla PRODUCT
# Tesla ORG
# Splunk Enterprise
#  FAC
# third ORDINAL
# PARIS GPE
# FRANCE GPE
# FEBRUARY 12 DATE
# Bitcoin GPE
# Bitcoin NORP
# February 12 DATE
# 202 CARDINAL
# Elon Musk PERSON
# almost $800 million MONEY
# Tesla PRODUCT
# first ORDINAL
# the New York Stock Exchange ORG
# NYSE ORG
# New York GPE
# U.S. GPE
# Tuesday, Jan. DATE
# U.S. GPE
# 10000 MONEY
# 10000 MONEY
# BTC ORG
# 225 CARDINAL
# Tokyo Stock Exchange ORG
# Tokyo GPE
# June 11, 2020 DATE
# Philip FONG / AFP PERSON
# PHILI NORP
# NEW YORK GPE
# NEW YORK GPE
# MAY 26 DATE
# the New York Stock Exchange ORG
# NYSE ORG
# the first day DATE
# thousands CARDINAL
# San Francisco Bay Area LOC
# two-thirds CARDINAL
# Crypto NORP
# three CARDINAL
# YouTube PRODUCT
# Elon Musk PERSON
# BTC ORG
# nearly USD $150,000 MONEY
# two days DATE
# LONDON GPE
# ENGLAND ORG
# Bitcoin PERSON
# August 15, 2018 DATE
# London GPE
# England GPE
# Brit ORG
# 102 CARDINAL
# Commercial Services Group ORG
# CSG ORG
# Bitcoin GPE
# third ORDINAL
# above $10,000 MONEY
# Bitcoin GPE
# 50% PERCENT
# Getty
#  PERSON
# 10,000 MONEY
# ten days DATE
# Bitcoin GPE
# Monday DATE
# evening TIME
# Bitcoin PERSON
# 50,000 MONEY
# $1 trillion MONEY
# the next several years DATE
# Satoshi Nakamoto PERSON
# Charlie Lee PERSON
# Tone Vays PERSON
# Emmanuel Goh PERSON
# John McAfee PERSON
# Kraken GPE
# Jimmy Song PERSON
# Getty
#  PERSON
# the United States GPE
# U.S. GPE
# WASHINGTON GPE
# JUNE 08 DATE
# U.S. GPE
# Donald Trump PERSON
# the White House ORG
# 133 MONEY
# $2.5 million MONEY
# $2.5 million MONEY
# Wednesday DATE
# morning TIME
# Spoooky PERSON
# BTC ORG
# Wednesday DATE
# CoinDesk's Markets Daily ORG
# noon TIME
# Bitcoin News Roundup ORG
# June 2, 2020 DATE
# 10 MONEY
# CoinDesk’s Markets Daily Podcast ORG
# Bitstamp PERSON
# Bloomberg PERSON
# BTC ORG
# 20K. MONEY
# CoinDesk’s Markets Daily Podcast ORG
# Bitstamp PRODUCT
# noon TIME
# January 3, 2009 DATE
# Satoshi Nakamoto PERSON
# Bitcoin GPE
# Bitcoin GPE
# BTC ORG
# CoinDesk's Markets Daily ORG
# The Stellar Development Foundation ORG
# year-to-date DATE
# +9123 WORK_OF_ART
# BTC ORG
# 10 MONEY
# JK Rowling ORG
# CoinDesk's Markets Daily Podcast ORG
# The Stellar Development Foundation ORG
# BTC ORG
# more than 6% PERCENT
# CoinDesk’s Markets Daily ORG
# noon TIME
# Chinese NORP
# BTC ORG
# multi-month DATE
# East LOC
# BTC ORG
# more than 1% PERCENT
# the day DATE
# CoinDesks Markets Daily ORG
# our regular noon TIME
# Russian NORP
# kissy-kissy PERSON
# Slack Technologies Inc. ORG
# $200 million MONEY
# a quarter DATE
# first ORDINAL
# Thursday DATE
# afternoon TIME
# recent days DATE
# Ten years ago DATE
# today DATE
# Byrne Hobart PERSON
# CoinDesk ORG
# New York GPE
# The Diff (diff.substack.com ORG
# +8235 WORK_OF_ART
# Telegram messenger PERSON
# Pavel Durov PERSON
# about $90,000 MONEY
# bitcoin GPE
# BTC ORG
# Russia GPE
# Egor Zhukov PERSON
# BTC ORG
# Polkadot ORG
# Polkadot ORG
# Inter PERSON
# NYSE ORG
# bitcoin GPE
# Litecoin, Ethereum GPE
# over 300 CARDINAL
# Tuesday DATE
# night TIME
# UMA Project ORG
# Bitcoin GPE
# above $10,000 MONEY
# first ORDINAL
# almost a month DATE
# U.S. GPE
# 7:05 p.m. TIME
# bitcoin PERSON
# BTC ORG
# 9,895 MONEY
# +1612 ORG
# One CARDINAL
# Bitcoin GPE
# Stockholm GPE
# Bitrefill PERSON
# Bitrefill Rewards Program ORG
# Bitrefill GPE
# Last month DATE
# Bitcoin GPE
# Bitcoin GPE
# 10,000 MONEY
# today DATE
# Chesnot/Getty Images ORG
# close to $10,000 MONEY
# the last few hours TIME
# Bitcoin GPE
# Filip Radwanski PERSON

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the ethereum text together

eth_text = []

for text in eth_df['text']:
    text = text
    eth_text.append(text)
    
big_string_eth = ' '.join(eth_text)

# %%
# Run the NER processor on all of the text
eth_doc = nlp(big_string_eth)

# Add a title to the document
eth_doc.user_data['title'] = 'Ethereum NER'

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Editor’s note:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andreessen HorowitzsCrypto Startup School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  brought together
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  participants from around the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and overseas in a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven-week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  course to learn how to build crypto companies.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andreessen Ho
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +3009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chars] Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , tell you whats been going on with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in … [+3095 chars] Editors note:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andreessen Horowitzs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto Startup School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  brought together
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  participants from around the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and overseas in a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven-week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  course to learn how to build crypto companies.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andreessen Ho
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Magic, a… [+2450 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Akron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ohio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the hometown of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LeBron James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the seat of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  tire industry;
# <mark class="entity" style="background: #bfe1d9; padding:

# %%
# List all Entities
for ent in eth_doc.ents:
    print (ent, ent.label_)
# Out:
# Andreessen HorowitzsCrypto Startup School ORG
# 45 CARDINAL
# U.S. GPE
# seven-week DATE
# Andreessen Ho PERSON
# +3009 ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Andreessen Horowitzs ORG
# Crypto Startup School ORG
# 45 CARDINAL
# U.S. GPE
# seven-week DATE
# Andreessen Ho PERSON
# Akron GPE
# Ohio GPE
# LeBron James PERSON
# US GPE
# the one hundred and twenty seventh DATE
# US GPE
# America GPE
# first ORDINAL
# 133 MONEY
# $2.5 million MONEY
# $2.5 million MONEY
# Wednesday DATE
# morning TIME
# The Linux Foundation ORG
# Drupal Foundation ORG
# OSI ORG
# Intel ORG
# CrossTalk ORG
# earlier in the year DATE
# March DATE
# 1500 CARDINAL
# well over a hundred CARDINAL
# the Mozilla Builders Incubator ORG
# more than £30,000 CARDINAL
# Bitcoin GPE
# Litecoin and Ethereum ORG
# Mark Andrews PERSON
# St Helens PERSON
# England GPE
# Liverpool Crown C ORG
# +2411 ORG
# Quantum ORG
# the next few years DATE
# New York City GPE
# United States GPE
# Jun. 10 DATE
# 130 MONEY
# 10,668 CARDINAL
# summer colonies DATE
# annual DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Phoenix GPE
# Sunday night TIME
# 10,500,839 CARDINAL
# May 31 DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# second ORDINAL
# 22% PERCENT
# ag ORG
# 219 MONEY
# Friday DATE
# 247 MONEY
# ConsenSys ORG
# Binance ORG
# Huobi GPE
# Osho Jha PERSON
# Crypto NORP
# +2372 WORK_OF_ART
# Blockchain GPE
# first ORDINAL
# blockchain GPE
# Bitcoin GPE
# Bitcoin PERSON
# Techmeme ORG
# 1:25 TIME
# June 13 DATE
# 2020 DATE
# 2020 DATE
# a big year DATE
# Bitcoin GPE
# Nexus Mutual ORG
# DeFi ORG
# the past 90 days DATE
# more than $4 million MONEY
# Nexus GPE
# Telegram PERSON
# Amulets WORK_OF_ART
# today DATE
# Version 2.0 LAW
# Sunday DATE
# India GPE
# Matic Foundation ORG
# 10 CARDINAL
# first ORDINAL
# the Basic Attention Token LAW
# the millions of dollars MONEY
# last week DATE
# Federal Reserve Board ORG
# Jerome H. Powell PERSON
# May 28, 2020 DATE
# The U.S. Patent and Trademark Office ORG
# Visa ORG
# one CARDINAL
# one CARDINAL
# Japanese NORP
# Tuesday DATE
# ConsenSys ORG
# Codefi Co… FAC
# The Ethereum Foundation ORG
# 2019 DATE
# the United Nations Childrens Fund ORG
# UNICEF ORG
# this week DATE
# second ORDINAL
# UNICEF ORG
# Cecilia Chapiro PERSON
# bitcoin GPE
# BTC ORG
# this week DATE
# 1.24 CARDINAL
# Ethereum PERSON
# Etherscan NORP
# Three CARDINAL
# Blockchain GPE
# ConsenSys ORG
# first ORDINAL
# Thursday DATE
# 86,390 MONEY
# ETH ORG
# around $2.6 million MONEY
# SparkPool ORG
# $2.5 million MONEY
# only sent $133 MONEY
# ETH ORG
# Shelton Qiu PERSON
# acc ORG
# +1217 ORG
# Bitcoin GPE
# ETH ORG
# BTC ORG
# ETH ORG
# second ORDINAL
# Canadian NORP
# SIM ORG
# Bitcoin GPE
# the year DATE
# two CARDINAL
# bitcoin GPE
# LONDON GPE
# June 16, 2020 DATE
# today DATE
# Huobi Wallet
#  ORG
# Huobi GPE
# first ORDINAL
# ETH ORG
# Tezos GPE
# Algorand GPE
# Qtum ORG
# Stake&amp;rdquo GPE
# algorithm ORG
# Michelangelo PERSON
# Phoenix GPE
# Sunday night TIME
# 10,500,839 CARDINAL
# May 31 DATE
# Ethereums ORG
# Tornado Cash PERSON
# ETH ORG
# 2016 DATE
# first ORDINAL
# MakerDAOs NORP
# Ethereums PRODUCT
# Sunday DATE
# India GPE
# Matic Foundation ORG
# 10 CARDINAL
# first ORDINAL
# first ORDINAL
# iOS GPE
# Android ORG
# a few months DATE
# a few thousand CARDINAL
# Ethereum 2.0 PRODUCT
# later this year DATE
# over $40,000 MONEY
# DEX PERSON
# Ethereum 2.0 FAC
# multiyear DATE
# blockchain GPE
# 2.0 CARDINAL
# San Francisco GPE
# Magic ORG
# $4 million MONEY
# New York GPE
# Jonathan Herzog PERSON
# YouTube PRODUCT
# Vitalik Buterin PERSON
# Monday DATE
# Glen Weyl PERSON
# Democrat NORP
# CoinDesk’s Markets Daily Bitcoin ORG
# Eastern ORG
# Ethereum (ETH ORG
# 2.0 CARDINAL
# Medium GPE
# +1837 GPE
# second ORDINAL
# 350 CARDINAL
# ETH ORG
# 86,000 MONEY
# $2.6 million MONEY
# less than 24 hours TIME
# first ORDINAL
# Ethereum 2.0 FAC
# ETH ORG
# Medium FAC
# Satoshi NORP
# just two days DATE
# May 18 DATE
# 10 CARDINAL
# Bitcoin GPE
# Fiatjaf GPE
# Bitcoin PERSON
# BTC ORG
# JPMorgan Chase &amp; ORG
# March DATE
# 3 CARDINAL
# blockchain GPE
# J. Christopher Giancarlo PERSON
# the Commodity Futures Trading Commission ORG
# CFTC ORG
# Milken Institute Global Conference ORG
# Beverly Hills GPE
# CFTC ORG
# the Ethereum (ETH ORG
# Bitcoin GPE
# BTC ORG
# 2.0 CARDINAL
# Cardano PERSON
# Apple ORG
# 40 CARDINAL
# Theta Token ORG
# Zilliqa PERSON
# ZIL ORG
# Elrond (ERD ORG
# $4 million MONEY
# Vodafone PERSON
# Energy Web PERSON
# Numerai ORG
# an additional $3 million MONEY
# NMR ORG
# Union Square Ventures ORG
# 17th ORDINAL
# second ORDINAL
# Skale Network CTO Konstantin Kladko ORG
# ETH ORG
# Eth PERSON
# ETH ORG
# a year ago DATE
# Deribit ORG
# 2.84% PERCENT
# Sunday DATE
# 1.04% PERCENT
# Saturday DATE
# the week DATE
# 4.92% PERCENT
# 2.4877 MONEY
# the day DATE
# BTCKeychain/Flickr
# Cryptocurrencies ORG
# YurikoNakao ORG
# the past few years DATE
# J.P. Koning PERSON
# CoinDesk ORG
# Canadian NORP
# Canadian NORP
# Blockchain GPE
# Thesis ORG
# BTC ORG
# BTC ORG
# Thesis ORG
# Grayscale Investments’ Ethereum Investment Trust ORG
# ETHE ORG
# 750% PERCENT
# Bitcoin GPE
# BTC ORG
# daily DATE
# about $20 billion MONEY
# June 11 DATE
# about $5 billion MONEY
# June 13 DATE
# Delphi Digital ORG
# 3.52% PERCENT
# Sunday DATE
# 5.93% PERCENT
# Saturday DATE
# EOS ORG
# the week DATE
# 7.59% PERCENT
# 2.6766 MONEY
# weekly DATE
# 5.39% PERCENT
# ConsenSys ORG
# Codefi Comp ORG
